# %% [markdown]
# # Q-Q Plots to Assess Normality and Outliers

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
np.random.seed(7134)

sample_size = 1000

# %%
uniform_data = np.random.uniform(0, 1, sample_size)
normal_data = np.random.normal(0, 1, sample_size)
exponential_data = np.random.exponential(1, sample_size)
gamma_data = np.random.gamma(2, 1, sample_size)

# %%
plt.figure(figsize=(16, 5))

#Uniform Histogram
plt.subplot(141)
plt.hist(uniform_data, bins=20, density=True, alpha=0.7)
plt.title("Uniform Histogram")

#Normal Histogram
plt.subplot(142)
plt.hist(normal_data, bins=20, density=True, alpha=0.7)
plt.title("Normal Histogram")

#Gamma Histogram
plt.subplot(143)
plt.hist(gamma_data, bins=20, density=True, alpha=0.7)
plt.title("Gamma Histogram")

#Exponential Histogram
plt.subplot(144)
plt.hist(exponential_data, bins=20, density=True, alpha=0.7)
plt.title("Exponential Histogram")


plt.show()

# %%
plt.figure(figsize=(16, 5))

#Uniform QQ plot
plt.subplot(141)
stats.probplot(uniform_data, dist="norm", plot=plt)
plt.title("Uniform Data - Normal QQ Plot")

#Normal QQ plot
plt.subplot(142)
stats.probplot(normal_data, dist="norm", plot=plt)
plt.title("Normal Data - Normal QQ Plot")

#Exponential QQ plot
plt.subplot(143)
stats.probplot(exponential_data, dist="norm", plot=plt)
plt.title("Exponential Data - Normal QQ Plot")

#Gamma QQ plot
plt.subplot(144)
stats.probplot(gamma_data, dist="norm", plot=plt)
plt.title("Gamma Data - Normal QQ Plot")

plt.show()

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

plt.figure(figsize=(16, 8))  

#Uniform Histogram
plt.subplot(241)
plt.hist(uniform_data, bins=20, density=True, alpha=0.7)
plt.title("Uniform Histogram")

#Normal Histogram
plt.subplot(242)
plt.hist(normal_data, bins=20, density=True, alpha=0.7)
plt.title("Normal Histogram")

#Exponential Histogram
plt.subplot(243)
plt.hist(exponential_data, bins=20, density=True, alpha=0.7)
plt.title("Exponential Histogram")

#Gamma Histogram
plt.subplot(244)
plt.hist(gamma_data, bins=20, density=True, alpha=0.7)
plt.title("Gamma Histogram")

#Uniform QQ Plot
plt.subplot(245)
stats.probplot(uniform_data, dist="norm", plot=plt)
plt.title("Uniform QQ Plot")

#Normal QQ Plot
plt.subplot(246)
stats.probplot(normal_data, dist="norm", plot=plt)
plt.title("Normal QQ Plot")

#Exponential QQ Plot
plt.subplot(247)
stats.probplot(exponential_data, dist="norm", plot=plt)
plt.title("Exponential QQ Plot")

#Gamma QQ Plot
plt.subplot(248)
stats.probplot(gamma_data, dist="norm", plot=plt)
plt.title("Gamma QQ Plot")

plt.tight_layout()
plt.show()
