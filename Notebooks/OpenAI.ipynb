# %%
import os
from pathlib import Path
import openai
from openai import OpenAI

# %%
#os.environ['OPENAI_API_KEY'] = 'KEY GOES HERE'

# %%
api_key = os.getenv('OPENAI_API_KEY')

#Initialize OpenAI API client
openai.api_key = api_key

# %%
#Text to speech
speech_file = "speech.mp3"
response = openai.audio.speech.create(
  model="tts-1",
  voice="alloy",
  input="This is a demonstration of text to speech using the Open AI API."
)
response.stream_to_file(speech_file)
# Out:
# /var/folders/mq/k4my6f796832wdwl98qv078w0000gn/T/ipykernel_14558/792627492.py:7: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file(speech_file)
