# %%
#Generalized Least Squares and Autocorrelation

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SalesData3.csv') #Switch to "SalesData.csv" for autocorrelation example
df.tail()
#df.dtypes
# Out:
#     MonthYear  TotalSales  AverageTemperature  TotalPrecip  LocalUE  \
# 51      45405         139                  57           87      2.7
# 52      45435         147                  67          176      3.0
# 53      45466         140                  74          134      3.5
# 54      45496         142                  78          196      3.6
# 55      45527         149                  76          298      3.7
#
#     Recession  Confidence  TERMCBAUTO48NS  UsedCPI     SandP500  ...  q3  q4  \
# 51          0        63.7        7.546667  191.199  4121.467362  ...   0   0
# 52          0        59.0        7.590000  199.646  4146.173196  ...   0   0
# 53          0        64.2        7.826667  198.746  4345.372838  ...   0   0
# 54          0        71.5        8.063333  196.086  4508.075488  ...   1   0
# 55          0        69.4        8.300000  193.671  4452.224726  ...   1   0
#
#      VDPs   SRPs  HandDPV  AppPV  NonSRPorVDP_PV  FormSuccess  SRPsandVDPs  \
# ...

# %%
xvars = ['AverageTemperature', 'TotalPrecip', 'LocalUE', 'Recession', 'TERMCBAUTO48NS', 'UsedCPI', 'SRPs', 'NonSRPorVDP_PV', 'VDPs', 'FormSuccess', 'demand_index', 'BOBBDC', 'TotalInventory', 'q2', 'q3', 'q4']
X = df[xvars]
y = df['TotalSales']

# %%
OLS_model = sm.OLS(y, X) 
OLS_results = OLS_model.fit()
OLS_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             TotalSales   R-squared (uncentered):                   0.991
# Model:                            OLS   Adj. R-squared (uncentered):              0.988
# Method:                 Least Squares   F-statistic:                              289.9
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):                    3.66e-36
# Time:                        15:08:47   Log-Likelihood:                         -227.91
# No. Observations:                  56   AIC:                                      487.8
# Df Residuals:                      40   BIC:                                      520.2
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
#Durbin-Watson Statistic 
dw_statistic = sm.stats.durbin_watson(OLS_results.resid)
print(f'Durbin-Watson statistic: {dw_statistic}')
# Out:
# Durbin-Watson statistic: 1.9686319282857698

# %%
#PACF plot
sm.graphics.tsa.plot_pacf(OLS_results.resid, lags=20)
plt.show()

# %%
GLS_model = sm.GLSAR(y, X, rho=1)  #rho is the order of autoregression
GLS_results = GLS_model.iterative_fit()
GLS_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 GLSAR Regression Results
# ...
# Dep. Variable:             TotalSales   R-squared (uncentered):                   0.991
# Model:                          GLSAR   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              261.2
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):                    1.56e-34
# Time:                        15:09:08   Log-Likelihood:                         -223.23
# No. Observations:                  55   AIC:                                      478.5
# Df Residuals:                      39   BIC:                                      510.6
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
OLS_params = OLS_results.params
GLS_params = GLS_results.params
param_frame = pd.DataFrame({"OLS": OLS_params, "GLS": GLS_params})
param_frame
# Out:
#                           OLS        GLS
# AverageTemperature   0.947817   1.022663
# TotalPrecip          0.033538   0.032503
# LocalUE             -5.014723  -5.613827
# Recession          -43.281947 -42.086576
# TERMCBAUTO48NS      13.711195  12.382328
# UsedCPI             -0.385562  -0.382920
# SRPs                -0.000558  -0.001096
# NonSRPorVDP_PV       0.001142   0.001611
# VDPs                 0.000642   0.001237
# FormSuccess          0.117706   0.103355
# demand_index         0.030311   0.032147
# BOBBDC              24.134631  26.305675
# TotalInventory       0.069463   0.032773
# q2                   2.271719   4.129941
# q3                 -19.853422 -19.402074
# q4                  -6.329031  -3.986713

# %%
xvars = ['AverageTemperature', 'TotalPrecip', 'LocalUE', 'Recession', 'TERMCBAUTO48NS', 'UsedCPI', 'SRPs', 'VDPs', 'FormSuccess', 'BOBBDC', 'TotalInventory', 'q2', 'q3', 'q4']
X = df[xvars]
y = df['TotalSales']

# %%
OLS_model = sm.OLS(y, X) 
OLS_results = OLS_model.fit()
OLS_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             TotalSales   R-squared (uncentered):                   0.991
# Model:                            OLS   Adj. R-squared (uncentered):              0.988
# Method:                 Least Squares   F-statistic:                              333.1
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):                    2.58e-38
# Time:                        15:12:17   Log-Likelihood:                         -229.11
# No. Observations:                  56   AIC:                                      486.2
# Df Residuals:                      42   BIC:                                      514.6
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
OLS_model = sm.OLS(y, X) 
OLS_results = OLS_model.fit()
OLS_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             TotalSales   R-squared (uncentered):                   0.991
# Model:                            OLS   Adj. R-squared (uncentered):              0.988
# Method:                 Least Squares   F-statistic:                              309.1
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):                    3.33e-37
# Time:                        15:10:57   Log-Likelihood:                         -228.60
# No. Observations:                  56   AIC:                                      487.2
# Df Residuals:                      41   BIC:                                      517.6
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...
