# %% [markdown]
# # Trilateration
# ### Given the distance from three points, find the location of the 4th

# %%
import numpy as np
from scipy.optimize import least_squares
import folium
from IPython.display import display

# %%
#Coordinates and their distances from Washington University 
hc = [38.75404, -90.4816] #Hollywood Casino - 11.60 miles away
bg = [38.61276, -90.25937] #Botanical Garden - 3.73 miles away
mt = [38.57304, -90.46289] #Museum of Transportation - 9.70 miles away

locations = np.array([hc,bg,mt])

#Distances to the each location in miles
#distances = np.array([11.6, 3.73, 9.7]) #10th's and 100th's
distances = np.array([12, 4, 10]) #Lower resolution

def haversine(coord1, coord2): #Calculate the great-circle distance between two points on Earth in decimal degrees.
    lat1, lon1 = np.radians(coord1)
    lat2, lon2 = np.radians(coord2)
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    return 3958.8 * c  #Earth's radius in miles

def residuals(x, locations, distances): #Calculate residuals for the optimization.
    return np.array([haversine(x, locations[i]) - distances[i] for i in range(len(locations))])

#Initial guess (mean of tower coordinates)
initial_guess = np.mean(locations, axis=0)

#Perform least squares optimization to find the point that minimizes the residuals
result = least_squares(residuals, initial_guess, args=(locations, distances))

#Extract the optimized coordinates
location = result.x
print(f"Estimated location: {location}")
# Out:
# Estimated location: [ 38.65240682 -90.30700202]

# %%
#Create a map centered around the estimated location
m = folium.Map(location=location, zoom_start=6)

#Add markers for the locations and estimated location
for i, (lat, lon) in enumerate(locations):
    folium.Marker([lat, lon], popup=f"Tower {i+1}").add_to(m)

folium.Marker(location, popup="Estimated Location", icon=folium.Icon(color='red')).add_to(m)

#Show the map
display(m)

#Save the map to an HTML file
#m.save("trilateration_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3869a19c737f5d7830c6daca104398a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3869a19c737f5d7830c6daca104398a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3869a19c737f5d7830c6daca104398a5 = L.map(
#                 &quot;map_3869a19c737f5d7830c6daca104398a5&quot;,
#                 {
#                     center: [38.652406819167844, -90.30700202222778],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a15836a87103c0d9a846de6ebd908620 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a15836a87103c0d9a846de6ebd908620.addTo(map_3869a19c737f5d7830c6daca104398a5);
#
#
#             var marker_36882e8e1e1a8b366481e01973345cf2 = L.marker(
#                 [38.75404, -90.4816],
#                 {}
#             ).addTo(map_3869a19c737f5d7830c6daca104398a5);
#
#
#         var popup_8bc949fa002097b76113952e308d3550 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_560fc9dc5e23348585061867a92c5ff8 = $(`&lt;div id=&quot;html_560fc9dc5e23348585061867a92c5ff8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 1&lt;/div&gt;`)[0];
#                 popup_8bc949fa002097b76113952e308d3550.setContent(html_560fc9dc5e23348585061867a92c5ff8);
#
#
#
#         marker_36882e8e1e1a8b366481e01973345cf2.bindPopup(popup_8bc949fa002097b76113952e308d3550)
#         ;
#
#
#
#
#             var marker_73254405de3117c5dc2fdfc895354521 = L.marker(
#                 [38.61276, -90.25937],
#                 {}
#             ).addTo(map_3869a19c737f5d7830c6daca104398a5);
#
#
#         var popup_a4cab9d80368fca5ddbd7e8131b60a7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6723e46c7e85d442dbdbbdc5bebc115a = $(`&lt;div id=&quot;html_6723e46c7e85d442dbdbbdc5bebc115a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 2&lt;/div&gt;`)[0];
#                 popup_a4cab9d80368fca5ddbd7e8131b60a7b.setContent(html_6723e46c7e85d442dbdbbdc5bebc115a);
#
#
#
#         marker_73254405de3117c5dc2fdfc895354521.bindPopup(popup_a4cab9d80368fca5ddbd7e8131b60a7b)
#         ;
#
#
#
#
#             var marker_6906b9c4d27538b4884b87bf925e2ab2 = L.marker(
#                 [38.57304, -90.46289],
#                 {}
#             ).addTo(map_3869a19c737f5d7830c6daca104398a5);
#
#
#         var popup_77d14c763d3010123c25f7bc1c67cd4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0526cbe7fc9169d0c89a2e438f65f40a = $(`&lt;div id=&quot;html_0526cbe7fc9169d0c89a2e438f65f40a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 3&lt;/div&gt;`)[0];
#                 popup_77d14c763d3010123c25f7bc1c67cd4b.setContent(html_0526cbe7fc9169d0c89a2e438f65f40a);
#
#
#
#         marker_6906b9c4d27538b4884b87bf925e2ab2.bindPopup(popup_77d14c763d3010123c25f7bc1c67cd4b)
#         ;
#
#
#
#
#             var marker_658858a326123b709cda80906af083c7 = L.marker(
#                 [38.652406819167844, -90.30700202222778],
#                 {}
#             ).addTo(map_3869a19c737f5d7830c6daca104398a5);
#
#
#             var icon_aebacd7d20a13247ecfb351513643858 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_658858a326123b709cda80906af083c7.setIcon(icon_aebacd7d20a13247ecfb351513643858);
#
#
#         var popup_020a164ae0b7bdefce4bd7ae29ab58df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_49a569d28744c04f4693a1695c768bb5 = $(`&lt;div id=&quot;html_49a569d28744c04f4693a1695c768bb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estimated Location&lt;/div&gt;`)[0];
#                 popup_020a164ae0b7bdefce4bd7ae29ab58df.setContent(html_49a569d28744c04f4693a1695c768bb5);
#
#
#
#         marker_658858a326123b709cda80906af083c7.bindPopup(popup_020a164ae0b7bdefce4bd7ae29ab58df)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
