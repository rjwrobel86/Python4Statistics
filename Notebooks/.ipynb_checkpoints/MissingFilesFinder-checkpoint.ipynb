# %%
#Find all files in folder 1 that are not in folder 2

import os

def get_all_files(folder):
    file_set = set()
    for root, _, files in os.walk(folder):
        for file in files:
            relative_path = os.path.relpath(os.path.join(root, file), folder)
            file_set.add(relative_path)
    return file_set

def find_missing_files(folder1, folder2):
    files_in_folder1 = get_all_files(folder1)
    files_in_folder2 = get_all_files(folder2)
    
    missing_files = files_in_folder1 - files_in_folder2
    return missing_files

#Example usage
folder1 = "/Users/robertwrobel/Library/Mobile Documents/com~apple~CloudDocs/Compiler /HME/New Folder With Items/Bomanda/"
folder2 = "/Volumes/Crucial X9/Backup/From Compiler - In Progress"

missing_files = find_missing_files(folder1, folder2)
for file in missing_files:
    print(file)
# Out:
# GH020215.MP4
# GH040257.MP4
# GH010063.mp4
# GH030181.MP4
# GS010035.mp4
# IMG_2075.MOV
# GH050498.MP4
# GH010217.MP4
# Movie on 2-9-22 at 5.12 AM.mov
# GH020211.MP4
# GH010088.mov
# IMG_1950 copy.mov
# GS010033.mp4
# GH020181.MP4
# IMG_0127.MOV
# Movie on 4-7-22 at 4.34 AM.mov
# GH020171.MP4
# GH010064.mp4
# GH040181.MP4
# GS010127.360
# GH010002 copy.MP4
# GH090498.MP4
# IMG_2076.MOV
# GH020066.mp4
# GH010219.MP4
# GH030138.MP4
# IMG_0131.MOV
# GH010003 copy.MP4
# GH020020.MP4
# GH010214.MP4
# GH010216.mov
# megansfw.mov
# GS040037 copy.mp4
# GH020178.MP4
# GS010026 copy.mp4
# GH010180.MP4
# GH010215.MP4
# GH010005.MP4
# GH030169.MP4
# GH010216.MP4
# GH090489.MP4
# GH040498.MP4
# GS010037 copy.mp4
# Movie on 1-26-22 at 2.48 PM copy.mov
# GH010257.MP4
# Movie on 2-9-22 at 4.09 AM.mov
# IMG_4979.MOV
# GH020005.MP4
# .DS_Store
# GH030211.MP4
# GH030257.MP4
# IMG_1763 copy 2.mov
# Video1648431560987.mp4
# IMG_1453.MOV
# GH010135.MP4
# GH010065.mp4
# GH060181.MP4
# Video1648239065924.mp4
# GH010123.MP4
# File 5.MOV
# GH080498.MP4
# GH100489.MP4
# GH020138.MP4
# EWXU3930.MP4
# GH020028 copy.MP4
# GH010493.MP4
# GH060498.MP4
# GH010022.mov
# GH020499.MP4
# IMG_1242.MOV
# GH010028 copy.MP4
# IMG_1763 copy.MOV
# GH010093.mov
# GH070498.MP4
# Video1648447166916.mp4
# GH020020.mov
# IMG_1763.mov
# GH010028.mov
# GH020498.MP4
# IMG_0011.MOV
# GS010127.mp4
# GH030498.MP4
# GH010066.mp4
# GH010128.MP4
# IMG_0426.MOV
# Movie on 4-7-22 at 4.26 AM.mov
# GH030499.MP4
# GH020028.mov
# GH040211.MP4
# Movie on 1-26-22 at 3.22 PM.mov
# GH010069v.mp4
# GH010495.MP4
# megansfw720.mov
# GH010085.mov
# GS010126.mp4
# GH010019.mov
# IMG_2531.MOV
# GH050211.MP4
# IMG_1950.mov
# IMG_1952 copy.mov
# GH010499.MP4
# GH010124.MP4
# Movie on 2-9-22 at 4.43 AM.mov
# IMG_0416.mov
# Screen Recording 2021-07-20 at 5.52.26 PM.mov
# GH010029 copy.MP4
# GS010034.mp4
# IMG_0015.MOV
# IMG_1952.mov
# GH020216.MP4
# GH110489.MP4
# GH010138.MP4
# GH020129.MP4
# Movie on 4-7-22 at 4.40 AM-Up to 4K.mov
# Movie on 2-9-22 at 4.15 AM.mov
# GH050257.MP4
# GL010028.MP4
# GH050181.MP4
# GH010129.MP4
# GH010498.MP4
# GH030066.mp4
# GH020170.MP4
# GH010122.MP4
# GH010023.mov
# GH010137.MP4
# GH040129.MP4

# %%
import os

folder1 = "/Users/robertwrobel/Library/Mobile Documents/com~apple~CloudDocs/Compiler /HME/New Folder With Items/Bomanda"
folder2 = "/Volumes/Crucial X9/Backup/New"
 
files_in_folder1 = set(os.listdir(folder1))
files_in_folder2 = set(os.listdir(folder2))

#Find files that are in folder1 but not in folder2
unique_to_folder1 = files_in_folder1 - files_in_folder2

# Output the results
unique_count = len(unique_to_folder1)
if unique_to_folder1:
    print(f"Count of files unique to folder1: {unique_count}")
    print("Files in folder1 but not in folder2:")
    for file in unique_to_folder1:
        print(file)
else:
    print("No unique files in folder1.")
