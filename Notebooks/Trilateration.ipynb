# %% [markdown]
# # Trilateration
# ### Given the distance from three points, find the location of the 4th

# %%
import numpy as np
from scipy.optimize import least_squares
import folium
from IPython.display import display

# %%
#Coordinates and their distances from Washington University 
hc = [38.75404, -90.4816] #Hollywood Casino - 11.60 miles away
bg = [38.61276, -90.25937] #Botanical Garden - 3.73 miles away
mt = [38.57304, -90.46289] #Museum of Transportation - 9.70 miles away

home = [38.57109, -90.29808] #12
work = [38.85720, -90.06833] #35
gs = [38.60840, -90.21133] #16

locations = np.array([home,work,gs])

#Distances to the each location in miles
#distances = np.array([11.6, 3.73, 9.7]) #10th's and 100th's
distances = np.array([12, 35, 16]) #Lower resolution

def haversine(coord1, coord2): #Calculate the great-circle distance between two points on Earth in decimal degrees.
    lat1, lon1 = np.radians(coord1)
    lat2, lon2 = np.radians(coord2)
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    return 3958.8 * c  #Earth's radius in miles

def residuals(x, locations, distances): #Calculate residuals for the optimization.
    return np.array([haversine(x, locations[i]) - distances[i] for i in range(len(locations))])

#Initial guess (mean of tower coordinates)
initial_guess = np.mean(locations, axis=0)

#Perform least squares optimization to find the point that minimizes the residuals
result = least_squares(residuals, initial_guess, args=(locations, distances))

#Extract the optimized coordinates
location = result.x
print(f"Estimated location: {location}")
# Out:
# Estimated location: [ 38.40170624 -90.3480774 ]

# %%
#Create a map centered around the estimated location
m = folium.Map(location=location, zoom_start=6)

#Add markers for the locations and estimated location
for i, (lat, lon) in enumerate(locations):
    folium.Marker([lat, lon], popup=f"Tower {i+1}").add_to(m)

folium.Marker(location, popup="Estimated Location", icon=folium.Icon(color='red')).add_to(m)

#Show the map
display(m)

#Save the map to an HTML file
#m.save("trilateration_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15a6289ed5a49ef3885717f4fb621afd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15a6289ed5a49ef3885717f4fb621afd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15a6289ed5a49ef3885717f4fb621afd = L.map(
#                 &quot;map_15a6289ed5a49ef3885717f4fb621afd&quot;,
#                 {
#                     center: [38.40170623625892, -90.34807739743917],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5356e7bffe491853a5ee02f6ce87aa37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5356e7bffe491853a5ee02f6ce87aa37.addTo(map_15a6289ed5a49ef3885717f4fb621afd);
#
#
#             var marker_c184c94d2794ab3bcd8bb15009f93715 = L.marker(
#                 [38.57109, -90.29808],
#                 {}
#             ).addTo(map_15a6289ed5a49ef3885717f4fb621afd);
#
#
#         var popup_ec3979d10ca668e99df7acab748375ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_657c0f86393a0a70b9dbb126f80614f2 = $(`&lt;div id=&quot;html_657c0f86393a0a70b9dbb126f80614f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 1&lt;/div&gt;`)[0];
#                 popup_ec3979d10ca668e99df7acab748375ba.setContent(html_657c0f86393a0a70b9dbb126f80614f2);
#
#
#
#         marker_c184c94d2794ab3bcd8bb15009f93715.bindPopup(popup_ec3979d10ca668e99df7acab748375ba)
#         ;
#
#
#
#
#             var marker_dac48e588a06f7f1f2cc538a2d39f3d4 = L.marker(
#                 [38.8572, -90.06833],
#                 {}
#             ).addTo(map_15a6289ed5a49ef3885717f4fb621afd);
#
#
#         var popup_e70a7bea1910fe02a31288ef97b6e3b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b3ece6b3bec0b823bd35dfdf4233e51 = $(`&lt;div id=&quot;html_7b3ece6b3bec0b823bd35dfdf4233e51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 2&lt;/div&gt;`)[0];
#                 popup_e70a7bea1910fe02a31288ef97b6e3b0.setContent(html_7b3ece6b3bec0b823bd35dfdf4233e51);
#
#
#
#         marker_dac48e588a06f7f1f2cc538a2d39f3d4.bindPopup(popup_e70a7bea1910fe02a31288ef97b6e3b0)
#         ;
#
#
#
#
#             var marker_029c50a3f2306b40a4002777d245fb5d = L.marker(
#                 [38.6084, -90.21133],
#                 {}
#             ).addTo(map_15a6289ed5a49ef3885717f4fb621afd);
#
#
#         var popup_b8b259697eb5f2e42207c5a693b120b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b262275f8e4053061640d1baca2666ef = $(`&lt;div id=&quot;html_b262275f8e4053061640d1baca2666ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 3&lt;/div&gt;`)[0];
#                 popup_b8b259697eb5f2e42207c5a693b120b8.setContent(html_b262275f8e4053061640d1baca2666ef);
#
#
#
#         marker_029c50a3f2306b40a4002777d245fb5d.bindPopup(popup_b8b259697eb5f2e42207c5a693b120b8)
#         ;
#
#
#
#
#             var marker_d391bb3ed6cf9fe58988351bd8e2b334 = L.marker(
#                 [38.40170623625892, -90.34807739743917],
#                 {}
#             ).addTo(map_15a6289ed5a49ef3885717f4fb621afd);
#
#
#             var icon_97d8eef468baac08e7d6a17c8e3e4a59 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d391bb3ed6cf9fe58988351bd8e2b334.setIcon(icon_97d8eef468baac08e7d6a17c8e3e4a59);
#
#
#         var popup_b04dfd951aaa1dc380cfa58e2bdb0f52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb1493132f619a1030652635f877d786 = $(`&lt;div id=&quot;html_bb1493132f619a1030652635f877d786&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estimated Location&lt;/div&gt;`)[0];
#                 popup_b04dfd951aaa1dc380cfa58e2bdb0f52.setContent(html_bb1493132f619a1030652635f877d786);
#
#
#
#         marker_d391bb3ed6cf9fe58988351bd8e2b334.bindPopup(popup_b04dfd951aaa1dc380cfa58e2bdb0f52)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
