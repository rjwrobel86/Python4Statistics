# %% [markdown]
# # Trilateration
# ### Given the distance from three points, find the location of the 4th

# %%
import numpy as np
from scipy.optimize import least_squares
import folium
from IPython.display import display

# %%
#Coordinates and their distances from Washington University 
hc = [38.75404, -90.4816] #Hollywood Casino - 11.60 miles away
bg = [38.61276, -90.25937] #Botanical Garden - 3.73 miles away
mt = [38.57304, -90.46289] #Museum of Transportation - 9.70 miles away

home = [38.57109, -90.29808] #12
work = [38.85720, -90.06833] #35
gs = [38.60840, -90.21133] #16

locations = np.array([home,work,gs])

#Distances to the each location in miles
#distances = np.array([11.6, 3.73, 9.7]) #10th's and 100th's
distances = np.array([12, 35, 16]) #Lower resolution

def haversine(coord1, coord2): #Calculate the great-circle distance between two points on Earth in decimal degrees.
    lat1, lon1 = np.radians(coord1)
    lat2, lon2 = np.radians(coord2)
    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    return 3958.8 * c  #Earth's radius in miles

def residuals(x, locations, distances): #Calculate residuals for the optimization.
    return np.array([haversine(x, locations[i]) - distances[i] for i in range(len(locations))])

#Initial guess (mean of tower coordinates)
initial_guess = np.mean(locations, axis=0)

#Perform least squares optimization to find the point that minimizes the residuals
result = least_squares(residuals, initial_guess, args=(locations, distances))

#Extract the optimized coordinates
location = result.x
print(f"Estimated location: {location}")
# Out:
# Estimated location: [ 38.40170624 -90.3480774 ]

# %%
#Create a map centered around the estimated location
m = folium.Map(location=location, zoom_start=6)

#Add markers for the locations and estimated location
for i, (lat, lon) in enumerate(locations):
    folium.Marker([lat, lon], popup=f"Tower {i+1}").add_to(m)

folium.Marker(location, popup="Estimated Location", icon=folium.Icon(color='red')).add_to(m)

#Show the map
display(m)

#Save the map to an HTML file
#m.save("trilateration_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37b7e0a369f80a69757d27685f4df995 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37b7e0a369f80a69757d27685f4df995&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37b7e0a369f80a69757d27685f4df995 = L.map(
#                 &quot;map_37b7e0a369f80a69757d27685f4df995&quot;,
#                 {
#                     center: [38.40170623625892, -90.34807739743917],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cae48c45f777fe74781d2749ba39807 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7cae48c45f777fe74781d2749ba39807.addTo(map_37b7e0a369f80a69757d27685f4df995);
#
#
#             var marker_e4bca13dc524ea4afdfa74c484bb95ef = L.marker(
#                 [38.57109, -90.29808],
#                 {
# }
#             ).addTo(map_37b7e0a369f80a69757d27685f4df995);
#
#
#         var popup_cf33112c74a3875602770930c702d8dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44fbc23c3bcd860a2d142aab3b0667ae = $(`&lt;div id=&quot;html_44fbc23c3bcd860a2d142aab3b0667ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 1&lt;/div&gt;`)[0];
#                 popup_cf33112c74a3875602770930c702d8dc.setContent(html_44fbc23c3bcd860a2d142aab3b0667ae);
#
#
#
#         marker_e4bca13dc524ea4afdfa74c484bb95ef.bindPopup(popup_cf33112c74a3875602770930c702d8dc)
#         ;
#
#
#
#
#             var marker_aae5226a8f707f3a88a1bbde74a1696f = L.marker(
#                 [38.8572, -90.06833],
#                 {
# }
#             ).addTo(map_37b7e0a369f80a69757d27685f4df995);
#
#
#         var popup_9595b4b6d7434324b50769b9edcbb8d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bdda86df0d9b308bb9fad95650a0024 = $(`&lt;div id=&quot;html_5bdda86df0d9b308bb9fad95650a0024&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 2&lt;/div&gt;`)[0];
#                 popup_9595b4b6d7434324b50769b9edcbb8d8.setContent(html_5bdda86df0d9b308bb9fad95650a0024);
#
#
#
#         marker_aae5226a8f707f3a88a1bbde74a1696f.bindPopup(popup_9595b4b6d7434324b50769b9edcbb8d8)
#         ;
#
#
#
#
#             var marker_232f2ef9a0bf7d9ec7380aa2b3212c98 = L.marker(
#                 [38.6084, -90.21133],
#                 {
# }
#             ).addTo(map_37b7e0a369f80a69757d27685f4df995);
#
#
#         var popup_e4ed82f975c7efe917c59654166aed6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7906b2dfa8fcd46278431eba1a6dcf21 = $(`&lt;div id=&quot;html_7906b2dfa8fcd46278431eba1a6dcf21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tower 3&lt;/div&gt;`)[0];
#                 popup_e4ed82f975c7efe917c59654166aed6f.setContent(html_7906b2dfa8fcd46278431eba1a6dcf21);
#
#
#
#         marker_232f2ef9a0bf7d9ec7380aa2b3212c98.bindPopup(popup_e4ed82f975c7efe917c59654166aed6f)
#         ;
#
#
#
#
#             var marker_df53ba341ea58a68516a28bf0f694294 = L.marker(
#                 [38.40170623625892, -90.34807739743917],
#                 {
# }
#             ).addTo(map_37b7e0a369f80a69757d27685f4df995);
#
#
#             var icon_d3b471b6cfe109bda391866414c2ab9a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_bec4315bfec8d74e5e7272d8e72f234b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8efa986b6a3c2c3e1b6b52b244f0846 = $(`&lt;div id=&quot;html_f8efa986b6a3c2c3e1b6b52b244f0846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estimated Location&lt;/div&gt;`)[0];
#                 popup_bec4315bfec8d74e5e7272d8e72f234b.setContent(html_f8efa986b6a3c2c3e1b6b52b244f0846);
#
#
#
#         marker_df53ba341ea58a68516a28bf0f694294.bindPopup(popup_bec4315bfec8d74e5e7272d8e72f234b)
#         ;
#
#
#
#
#                 marker_df53ba341ea58a68516a28bf0f694294.setIcon(icon_d3b471b6cfe109bda391866414c2ab9a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
