# %% [markdown]
# # Quantile Regresson

# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/SalesData.csv')
df.head()
# Out:
#   MonthYear  TotalSales  AverageTemperature  TotalPrecip  LocalUE  Recession  \
# 0    12-Aug         121                  78          127      7.6          0
# 1    12-Sep          78                  68          204      7.0          0
# 2    12-Oct          93                  57          151      6.9          0
# 3    12-Nov          92                  46           92      6.9          0
# 4    12-Dec          99                  42          108      7.1          0
#
#    Confidence  TERMCBAUTO48NS  UsedCPI     SandP500  ...  GAPageviews  Leads  \
# 0        74.3        4.880000  150.871  1403.448258  ...         8407    358
# 1        78.3        4.860000  149.647  1443.419472  ...        24116    271
# 2        82.6        4.840000  148.986  1437.816662  ...        24473    312
# 3        82.7        4.820000  148.932  1394.512387  ...        22900    275
# 4        72.9        4.776667  149.243  1422.285492  ...        23321    255
#
# ...

# %%
ols_model = smf.ols('TotalSales ~ TotalInventory + AverageTemperature + UsedCPI + q2 + q3 + q4', df)
ols_model_result = ols_model.fit()
ols_model_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             TotalSales   R-squared:                       0.412
# Model:                            OLS   Adj. R-squared:                  0.384
# Method:                 Least Squares   F-statistic:                     14.74
# Date:                Wed, 12 Jun 2024   Prob (F-statistic):           1.05e-12
# Time:                        15:03:38   Log-Likelihood:                -625.21
# No. Observations:                 133   AIC:                             1264.
# Df Residuals:                     126   BIC:                             1285.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
#25th Percentile
quantile_model_25 = smf.quantreg('TotalSales ~ TotalInventory + AverageTemperature + UsedCPI + q2 + q3 + q4', df)
quantile_result_25 = quantile_model_25.fit(q=0.25)
quantile_result_25.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          QuantReg Regression Results
# ...
# Dep. Variable:             TotalSales   Pseudo R-squared:               0.2179
# Model:                       QuantReg   Bandwidth:                       19.80
# Method:                 Least Squares   Sparsity:                        69.44
# Date:                Wed, 12 Jun 2024   No. Observations:                  133
# Time:                        15:03:38   Df Residuals:                      126
#                                         Df Model:                            6
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            -18.1757     24.235     -0.750      0.455     -66.135      29.784
# TotalInventory         0.5496      0.074      7.385      0.000       0.402       0.697
# ...

# %%
#Median Quantile
quantile_model = smf.quantreg('TotalSales ~ TotalInventory + AverageTemperature + UsedCPI + q2 + q3 + q4', df)
median_quantile_result = quantile_model.fit(q=0.5)
median_quantile_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          QuantReg Regression Results
# ...
# Dep. Variable:             TotalSales   Pseudo R-squared:               0.2732
# Model:                       QuantReg   Bandwidth:                       23.32
# Method:                 Least Squares   Sparsity:                        63.18
# Date:                Wed, 12 Jun 2024   No. Observations:                  133
# Time:                        15:03:39   Df Residuals:                      126
#                                         Df Model:                            6
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             14.9673     27.149      0.551      0.582     -38.761      68.695
# TotalInventory         0.6226      0.087      7.121      0.000       0.450       0.796
# ...

# %%
#75th Percentile
quantile_model_75 = smf.quantreg('TotalSales ~ TotalInventory + AverageTemperature + UsedCPI + q2 + q3 + q4', df)
quantile_result_75 = quantile_model_75.fit(q=0.75)
quantile_result_75.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          QuantReg Regression Results
# ...
# Dep. Variable:             TotalSales   Pseudo R-squared:               0.3097
# Model:                       QuantReg   Bandwidth:                       24.41
# Method:                 Least Squares   Sparsity:                        91.35
# Date:                Wed, 12 Jun 2024   No. Observations:                  133
# Time:                        15:03:39   Df Residuals:                      126
#                                         Df Model:                            6
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              6.7695     34.519      0.196      0.845     -61.542      75.081
# TotalInventory         0.7331      0.112      6.527      0.000       0.511       0.955
# ...

# %%
model = smf.quantreg('TotalSales ~ TotalInventory + AverageTemperature + UsedCPI + q2 + q3 + q4', df)
list_of_quantiles = [0.10,0.25,0.75,0.99]
params_list = []

for i in list_of_quantiles:
    result = model.fit(q=i)
    params_list.append(result.params)
    
params_list
# Out:
# [Intercept            -28.754973
#  TotalInventory         0.254143
#  AverageTemperature     0.190260
#  UsedCPI                0.456351
#  q2                     2.642243
#  q3                    -0.899753
#  q4                     0.699000
#  dtype: float64,
#  Intercept            -18.175732
#  TotalInventory         0.549614
#  AverageTemperature    -0.346543
#  UsedCPI                0.359226
#  q2                    12.818994
#  q3                    11.075261
#  q4                    -6.219839
#  dtype: float64,
#  Intercept             6.769454
#  TotalInventory        0.733082
#  AverageTemperature    0.331299
#  UsedCPI               0.056088
#  q2                    0.067159
#  q3                   -9.566732
#  q4                   -3.932297
#  dtype: float64,
#  Intercept             140.412212
#  TotalInventory          0.354553
#  AverageTemperature      1.624968
#  UsedCPI                -0.469895
#  q2                    -41.460300
# ...
