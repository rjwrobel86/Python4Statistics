# %% [markdown]
# # The "Law of Large Numbers"
# ## LLN shows us that the larger our sample is, relative to the population, the closer our sample mean will be to the population mean / expected value

# %%
import numpy as np
import matplotlib.pyplot as plt

#Generate normally distributed data
mean = 100
std_dev = 25
size = 10000
data = np.random.normal(mean, std_dev, size)
population_mean = np.mean(data)
print(population_mean)
# Out:
# 99.85981498502478

# %%
#Sample the data
sample_sizes = [10, 50, 100, 250, 500, 750, 999, 2500 ,5000, 7500, 9000, 9999]
#Create empty lists to store calculations
means = []
differences = []

#Loop through the sample_sizes list and take a sample of each size
#Calculate the mean of each sample, then append it to the means list
#Calculate how far the each sample mean is from the population mean, then append it to the differences list
for i in sample_sizes:
    sample = np.random.choice(data, size=i)
    mean = np.mean(sample)
    print(f"The sample mean is {mean}\n")
    means.append(mean)
    dif = abs(population_mean - mean)
    print(f"The difference between the population and sample mean is {dif} when the sample size is {i} \n")
    differences.append(dif)
# Out:
# The sample mean is 104.16311537822571
#
# The difference between the population and sample mean is 4.303300393200928 when the sample size is 10
#
# The sample mean is 100.86621425377069
#
# The difference between the population and sample mean is 1.0063992687459091 when the sample size is 50
#
# The sample mean is 99.30358578440848
#
# The difference between the population and sample mean is 0.5562292006163005 when the sample size is 100
#
# The sample mean is 100.39814906700511
#
# The difference between the population and sample mean is 0.5383340819803237 when the sample size is 250
#
# The sample mean is 99.560783850531
#
# The difference between the population and sample mean is 0.29903113449378793 when the sample size is 500
#
# The sample mean is 99.32859043817781
#
# The difference between the population and sample mean is 0.5312245468469712 when the sample size is 750
#
# The sample mean is 100.7926598867851
#
# The difference between the population and sample mean is 0.9328449017603191 when the sample size is 999
#
# The sample mean is 100.62274783471487
#
# The difference between the population and sample mean is 0.7629328496900882 when the sample size is 2500
#
# The sample mean is 100.12058448855947
#
# The difference between the population and sample mean is 0.2607695035346893 when the sample size is 5000
#
# The sample mean is 100.00319006894901
#
# The difference between the population and sample mean is 0.1433750839242265 when the sample size is 7500
#
# The sample mean is 99.76502717205949
#
# The difference between the population and sample mean is 0.09478781296529348 when the sample size is 9000
#
# The sample mean is 99.7782978313132
#
# The difference between the population and sample mean is 0.0815171537115873 when the sample size is 9999

# %%
#Zip the two lists into a "Zip object"
sizes_and_diffs_zip = zip(sample_sizes, differences) 
#Convert the "Zip object" into a list of tuples, pairs of size and corresponding differences
sizes_and_diffs_list = list(sizes_and_diffs_zip)
print(sizes_and_diffs_list)
# Out:
# [(10, 4.303300393200928), (50, 1.0063992687459091), (100, 0.5562292006163005), (250, 0.5383340819803237), (500, 0.29903113449378793), (750, 0.5312245468469712), (999, 0.9328449017603191), (2500, 0.7629328496900882), (5000, 0.2607695035346893), (7500, 0.1433750839242265), (9000, 0.09478781296529348), (9999, 0.0815171537115873)]

# %%
#Plot the sample size vs the error (estimated mean vs actual)
plt.scatter(sample_sizes, differences)
plt.plot(sample_sizes, differences, '-', color='red', label='Line')
plt.title('Sample Size vs Error')
plt.show()

# %%
#Plot the sample size vs the error (estimated mean vs actual)
plt.scatter(sample_sizes, differences)
plt.plot(sample_sizes, differences, '-', color='red', label='Line')
plt.title('Trials vs Difference In Theoretical vs Actual Probability')
plt.show()
